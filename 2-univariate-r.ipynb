# %% [markdown]
# Here mtcars is a dataset.

# %%
data(mtcars)
names(mtcars)

# %% [markdown]
# ### We can use the summary() function to quickly summarize each variable in the dataset:

# %%
summary(mtcars)

# %% [markdown]
# ### mean means all the outcome/total no. of elements (average) and $ gives access to single column so here mpg is a column.
# ****

# %%
mean(mtcars$mpg)

# %% [markdown]
# ### **median is a statistical measure that determines the middle value of dataset listed in ascending order.**

# %%
median(mtcars$mpg)

# %% [markdown]
# ### minimum value of the dataset column

# %%
min(mtcars$mpg)
min(mtcars$)

# %%
 ## For detailed discussion on the same, refere to reading material for the module
data(mtcars)


# ------------------------------------------------------------------------
mean(mtcars$mpg)
median(mtcars$mpg)
min(mtcars$mpg)
max(mtcars$mpg)
var(mtcars$mpg)
sd(mtcars$mpg)

# %%
 ## For detailed discussion on the same, refere to reading material for the module
data(mtcars)


# ------------------------------------------------------------------------
mean(mtcars$mpg)
median(mtcars$mpg)
min(mtcars$mpg)
max(mtcars$mpg)
var(mtcars$mpg)
sd(mtcars$mpg)
